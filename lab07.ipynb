# %% [markdown]
# # НИС «Основы анализа данных в Python»
#
# *Алла Тамбовцева*
#
# ## Лабораторная работа №7

# %% [markdown]
# ### Задание 1 (1 балл)
#
# В файле [task01.csv](https://github.com/allatambov/PyDat25/blob/main/task01.csv) хранится небольшой искусственно сгенерированный набор данных.
#
# *(0.5 балла)* Постройте матрицу диаграмм рассеивания для всех пар числовых показателей в файле `task01.csv`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# *(0.5 балла)* Основываясь только на полученных диаграммах, укажите пару показателей, для которой значение коэффициента корреляции Пирсона будет наибольшим по модулю. Обоснуйте свой ответ.

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 2 (4 балла)
#
# В файле [economy.csv](https://github.com/allatambov/PyDat25/blob/main/economy.csv) хранятся значения некоторых индикаторов, входящих в индекс экономических свобод (*Economic Freedom Index*), а именно:
#
# * индекс прав собственности
# * индекс эффективности судебной системы
# * индекс финансового здоровья
# * индекс свободы бизнеса
# * индекс свободы инвестиций
# * индекс финансовой свободы
# * уровень налогового бремени в % к ВВП.
#
#
# *(0.5 балла)* Постройте корреляционную матрицу (с коэффициентами Пирсона) для показателей, между которыми можно вычислить содержательно интерпретируемый коэффициент корреляции. Округлите значения коэффициентов корреляции в матрице до сотых.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# *(1 балл)* Сфокусируйтесь на парах показателей, для которых полученный коэффициент не ниже 0.3 по модулю.  Выберите среди них пару показателей с наименьшим по модулю коэффициентом. Для этой пары переменных проверьте, можно ли считать, что между ними есть статистически значимая линейная связь (на 5% уровне значимости).
#
# Напишите нужный код для проверки гипотезы, сделайте вывод об отвержении/не отвержении нулевой гипотезы и о наличии связи.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# *(0.5 балла)* Постройте корреляционную матрицу (с коэффициентами Спирмена) для тех же показателей, что и в первом пункте задания. Округлите значения коэффициентов корреляции в матрице до сотых.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# *(1 балл)* Вычислите разницу в коэффициентах Пирсона и Спирмена, полученных в предыдущих пунктах – постройте матрицу с абсолютными значениями разностей коэффициентов для всех пар показателей. Найдите пару с самой большой абсолютной разницей, постройте для этих показателей [диаграмму рассеивания](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.scatter.html). Прокомментируйте, почему в данном случае значения коэффициентов Спирмена и Пирсона могут относительно сильно отличаться.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# *(1 балл)* Вычислите коэффициенты корреляции Пирсона между индексом прав собственности и индексом свободы инвестиций для каждого региона отдельно. В каком регионе значение коэффициента наибольшее? Найдите его название **с помощью соответствующего кода**.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задание 3 (2 балла)
#
# В файле [s-depression.csv](https://github.com/allatambov/PyDat25/blob/main/s-depression.csv) хранятся результаты опроса (источник – Kaggle), посвященного психологическому здоровью студентов:
#
# * пол и возраст студента;
# * уровень учебной нагрузки (восприятие студентом в шкале от 1 до 5);
# * средний общий балл;
# * уровень удовлетворения от учебы (восприятие студентом в шкале от 1 до 5);
# * продолжительность сна;
# * пищевые привычки;
# * уровень образования (бакалавры – названия, начинающиеся с `B`, магистры – с `M`, также есть категории `PhD` и `Others`);
# * ответ на вопрос о наличии суицидальных мыслей;
# * наличие депрессии.
#
# *(1 балл)* Выберите подходящий коэффициент корреляции (Пирсона/Спирмена) для оценки связи между *уровнем учебной нагрузки* и *уровнем удовлетворения от учебы*. **Обоснуйте свой ответ, ответ без обоснования не засчитывается**.
#
# *(1 балл)* Вычислите коэффициент корреляции и проверьте на 5% уровне значимости, можно ли считать, что связь между показателями есть. При необходимости выполните дополнительные манипуляции с данными. **Сделайте вывод о наличии/отсутствии связи.**

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **ОТВЕТ**

# %% [markdown]
# ### Задание 4 (3 балла)
#
# Используя данные из файла `s-depression.csv` из предыдущей задачи, проверьте, есть ли связь между продолжительностью сна и наличием депрессии у бакалавров. Для этого:
#
# *(1 балл)* Выберите строки, соответствующие бакалаврам, у которых указана продолжительность сна (не `Other`).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# *(2 балла)* Используя подходящий статистический критерий, проверьте на 10%-ном уровне значимости, есть ли связь между продолжительностью сна и наличием депрессии у бакалавров. **Сделайте вывод.**

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **ОТВЕТ**
