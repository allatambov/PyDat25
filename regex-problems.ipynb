# %% [markdown]
# # НИС «Основы анализа данных в Python»
#
# *Алла Тамбовцева*
#
# ## Дополнительные задачи на регулярные выражения в `pandas`

# %% [markdown]
# Данные для работы можно скачать [здесь](https://disk.yandex.ru/d/snh8mdwZVsuH0A).
#
# В файле `orders.csv` хранится общая информация о заказах пиццы:
#
# * `order_id`: id заказа;
# * `date`: дата заказа;
# * `time`: время заказа.
#
# В файле `order_details.csv` хранится более подробная информация о заказах пиццы:
#
# * `order_details_id`: id записи (одной пиццы в заказе);
# * `order_id`: id заказа;
# * `pizza_id`: id пиццы, состоит из её названия (с `_` вместо пробелов) и её размера (`l/m/s/xl/xxl`, после последнего `_`);
# * `quantity`: число пицц с данным id в заказе.

# %% [markdown]
# ### Задача 1
#
# Загрузите данные из файлов `orders.csv` и `order_details.csv`. Объедините данные по столбцу `order_id` и сохраните итоговый датафрейм в переменную `full`.
#
# **Подсказка:** метод `.merge()`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# **Примечание.** Кто знаком с объединением таблиц или баз данных (разные варианты JOIN), в данном случае использование `.merge()` и `.join()` дает одинаковый результат, так как в обоих датафреймах есть все значения `order_id`. У этих методов есть свои особенности, но ключевое отличие в новой версии `pandas` такое: `.merge()` по умолчанию осуществляет INNER JOIN, а `.join()` – LEFT JOIN. Подробнее – см, например, [статью](https://www.geeksforgeeks.org/sql-join-set-1-inner-left-right-and-full-joins/) о типах объединений.

# %% [markdown]
# ### Задача 2
#
# Добавьте в датафрейм `full`:
#
# * столбец `pizza_size` с размером пиццы заглавными буквами (значения из `pizza_id` после последнего `_`);
# * столбец `pizza_type` с названием пиццы без указания её размера (значения из `pizza_id` до `_m`, `_l` и проч).
#
# Примеры значений для первых трёх заказов:
#
# * название `hawaiian` и размер `M`;
# * название `classic_dlx` и размер `M`;
# * название `five_cheese` и размер `L`.
#
# **Важно:** для тренировки используйте метод `str.extract()` и поиск по группам, а также метод `.str.upper()`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Добавьте в датафрейм `full`:
#
# * столбец `year` с годом из даты заказа;
# * столбец `month` с месяцем из даты заказа;
# * столбец `day` с месяцем из даты заказа;
#
# **Важно:** для тренировки используйте метод `str.extract()`, не приводите столбец с датой к типу *datetime*.

# %%
### YOUR CODE HERE ###
