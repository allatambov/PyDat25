# %% [markdown]
# # НИС «Основы анализа данных в Python»
#
# *Алла Тамбовцева*
#
# ## Лабораторная работа №4
#
# В файле `air.csv` (скачать [здесь](https://github.com/allatambov/PyDat25/blob/main/air.csv)) хранятся результаты измерения разных характеристик качества воздуха в Нью-Йорке с мая по сентябрь 1973 года (исторические данные из R).
#
# Переменные в файле:
#
# * `Ozone`: содержание озона в воздухе (среднее число частиц на биллион);
# * `Solar.R`: количество солнечной энергии/уровень солнечной радиации (в Лэнгли);
# * `Wind`: скорость ветра (в милях в час);
# * `Temp`: максимальная температура в градусах по Фаренгейту;
# * `Month`: месяц наблюдения (целое число);
# * `Day`: день наблюдения (целое число).
#
# Загрузите данные из файла `air.csv` и выполните задания.

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Вычислите число пропущенных значений в столбце `Ozone`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (1 балл)
#
# Опираясь на пример заполнения пропусков с учётом группировки из практикума 7, заполните пропуски в `Ozone` средними значениями этого признака, рассчитанными за каждый месяц (`Month`).
#
# **Сохраните изменения в датафрейме, это важно для последующих задач.**

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Удалите выбросы в столбце `Ozone` по критерию 1.5×IQR. Сохраните очищенный датафрейм в переменную `df_clean01`. Укажите количество строк в полученном датафрейме.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (2 балла)
#
# Удалите выбросы в столбце `Ozone` по критерию 2×STD. Сохраните очищенный датафрейм в переменную `df_clean02`. Укажите количество строк в полученном датафрейме.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (2 балла)
#
# Выберите строки, соответствующие наблюдениям, которые считаются нехарактерными по критерию 1.5×IQR, и сохраните датафрейм в переменную `out01`. Заберите индексы строк `out01` (атрибут `.index`) и превратите результат в множество `set01`.
#
# Выберите строки, соответствующие наблюдениям, которые считаются нехарактерными по критерию 2×STD, и сохраните датафрейм в переменную `out02`. Заберите индексы строк `out02` (атрибут `.index`) и превратите результат в множество `set02`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (2 балла)
#
# Используя операции на множествах, определите:
#
# * какие наблюдения были признаны выбросами как и по критерию 1.5×IQR, так и по критерию 2×STD;
# * какие наблюдения были признаны выбросами по критерию 1.5×IQR, но не по критерию 2×STD;
# * какие наблюдения были признаны выбросами по критерию 2×STD, но не по критерию 1.5×IQR.
#
# Помимо кода напишите ответ (можно комментарием, чтобы было понятно, какая выдача кода какому пункту соответствует).

# %%
### YOUR CODE HERE ###
