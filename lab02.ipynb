# %% [markdown]
# # НИС «Основы анализа данных в Python»
#
# *Алла Тамбовцева*
#
# ## Лабораторная работа №2

# %% [markdown]
# ### Задача 1 (1 балл)
#
# В списке `words` сохранены слова. Используя функцию `map()`, создайте новый список, состоящий из количества букв в каждом слове.

# %%
words = ["каждый", "охотник", "желает", "знать", "где", "сидит", "фазан"]

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (1 балл)
#
# В списке `headings` сохранены заголовки новостей с сайта [nplus1.ru](https://nplus1.ru/). Используя функцию `map()`, создайте новый список заголовков, где в каждом заголовке слова написаны с большой буквы (например, *Орбитальный Зонд LRO Заметил На Луне Свежий Кратер*).

# %%
headings = ["Орбитальный зонд LRO заметил на Луне свежий кратер", 
           "Нападки сородичей в детстве улучшили когнитивные способности ворон-свистунов", 
           "Людей позднего бронзового века заподозрили в использовании желтой растительной краски",
           "Муравьи-паразиты обманом заставили муравьев-хозяев убить собственных матерей",
           "Головная боль затронула каждого третьего жителя Земли"]

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (1 балл)
#
# В списке `L` сохранены значения температуры в градусах по Фаренгейту. Используя функцию `map()`, создайте новый список со значениями температуры в градусах по Цельсию, считая, что перевод осуществляется так:
#
# $$
# t_C = \frac{5}{9}(t_F - 32)
# $$

# %%
L = [-40, -20, 25, 30, 42, 100, 150, 451]

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (2 балла)
#
# В списке `from_input` сохранены строки, внутри которых содержатся доли верно ответивших на вопросы викторины из 12 вопросов.
# Используя функцию `map()`, создайте новый список с теми же долями, переведенными в проценты, с точностью до сотых.

# %%
from_input = ["0.9333", "0.4666", "0.5666", "0.41", "0.8666", "0.6", 
              "0.9266", "0.033", "0.58", "0.5333", "0.9633", "0.8"]

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (1 балл)
#
# В массивах сохранены данные по заказам разных видов кофе (их 7) в кофейне «Случайный лес», сделанных в течение 4.5 часов:
#
# * `coffee_price`: цены разных видов кофе;
# * `coffee_orders`: число заказов кофе каждого вида.
#
# Используя эти массивы, вычислите выручку от полученных заказов.

# %%
import numpy as np

coffee_price = np.array([270, 320, 220, 170, 270, 370, 400])
coffee_orders = np.array([10, 6, 12, 16, 8, 11, 2])

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (2 балла)
#
# В массивах сохранены данные по заказам разных видов кофе в кофейне «Случайный лес», сделанным 10 посетителями:
#
# * `name`: названия заказанных видов кофе;
# * `price`: цены разных видов кофе;
# * `milk`: факт приготовления кофе на альтернативном молоке (1 – альтернативное, 0 – обычное), добавляет 40 рублей к стоимости.
#
# Известно, что в период наблюдения в кофейне действует скидка 10% на заказ любого вида эспрессо.
#
# Создайте массив с *итоговой стоимостью* заказа посетителей – сколько заплатил с учетом всех факторов каждый из 10 гостей.

# %%
name = np.array(["Эспрессо Дикий бутстрап", 
                 "Латте Решающий пень в весенний день", 
                 "Эспрессо Дикий бутстрап",
                 "Капучино Священный рандом", 
                 "Капучино Священный рандом", 
                 "Латте Решающий пень в весенний день", 
                 "Эспрессо Утро в случайном лесу", 
                 "Латте Дедлайн, который превратился в тыкву", 
                 "Фильтр-кофе Простокофе", 
                 "Капучино Священный рандом"])

price = np.array([220, 300, 220, 270, 270, 300, 220, 300, 180, 270])
milk = np.array([0, 0, 0, 1, 0, 1, 0, 0, 0, 1])

### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7 (2 балла)
#
# Напишите функцию `convert()`, которая принимает на вход слово с названием цвета (считаем, что их два, `black` и `white`) и «производит» инверсию – черный цвет меняет на белый, и наоборот. Другими словами, на слово `black` функция должна возвращать `white`, а на слово `white` – `black`.
#
# Векторизуйте эту функцию и получите на основе списка `colors` список инвертированных цветов.

# %%
colors = ["black", "white", "white", "black", "black", "white", 
         "white", "white", "black", "black", "black"]

### YOUR CODE HERE ###
