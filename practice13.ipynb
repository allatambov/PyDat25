# %% [markdown]
# # НИС «Основы анализа данных в Python»
#
# *Алла Тамбовцева*
#
# ## Практикум 13. Сравнение двух групп:  визуализация и проверка гипотез

# %% [markdown]
# Необходимые импорты:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from scipy import stats
from matplotlib import pyplot as plt

# %% [markdown]
# ## Часть 1: сравнение двух групп – визуализация и анализ

# %% [markdown]
# В файле `BPL.csv` хранятся данные по клиентам банка, которым было предложено взять потребительский кредит:
#
# * `Age` и `Experience`: возраст и стаж клиента;
# * `ZIP Code`: почтовый индекс клиента;
# * `Family`: количество человек в семье;
# * `Education`: уровень образования (1 – `undergrad`, 2 – `graduate`, 3 – `advanced/professional`);
# * `Income`: годовой доход (в тысячах долларов);
# * `CCAvg`: среднемесячные траты по кредитным картам (в тысячах долларов);
# * `Mortgage`: платежи по ипотеке (в тысячах долларов);
# * `Securities Account`: есть ли у клиента счет ценных бумаг в этом банке;
# * `CD Account`: есть ли у клиента срочный банковский вклад в этом банке;
# * `Online`: использует ли клиент онлайн-сервисы этого банка;
# * `CreditCard`: наличие у клиента кредитной карты этого банка;
# * `Personal Loan`: согласился ли оформить потребительский кредит.

# %%
df = pd.read_csv("https://raw.githubusercontent.com/allatambov/PyDat25/refs/heads/main/BPL.csv")

# %% [markdown]
# ### Задача 1
#
# Вам необходимо сравнить средний возраст клиентов, которые согласились и не согласились взять потребительский кредит в этом банке.
#
# 1. Сравните описательные статистики возраста клиентов в двух группах.
# 2. Используя [функцию](https://seaborn.pydata.org/generated/seaborn.violinplot.html) `violinplot()` из библиотеки `seaborn`, постройте скрипичные диаграммы для распределения возраста в двух группах. Прокомментируйте полученные результаты, в частности, отметьте, можно ли считать распределение в двух группах нормальным.
# 3. Подтвердите вывод относительно нормальности распределения возраста в двух группах, используя критерий Шапиро-Уилка и приняв уровень значимости равным 5%.
# 4. Выбрав подходящий вариант статистического теста, проверьте на 5% уровне значимости, есть ли отличия в средних значениях/распределении возраста в двух группах.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Вам необходимо сравнить доход клиентов, которые согласились и не согласились взять потребительский кредит в этом банке.
#
# 1. Сравните описательные статистики дохода клиентов в двух группах.
# 2. Используя [функцию](https://seaborn.pydata.org/generated/seaborn.violinplot.html) `violinplot()` из библиотеки `seaborn`, постройте скрипичные диаграммы для распределения дохода в двух группах. Прокомментируйте полученные результаты, в частности, отметьте, можно ли считать распределение в двух группах нормальным.
# 3. Подтвердите вывод относительно нормальности распределения дохода в двух группах, используя критерий Шапиро-Уилка и приняв уровень значимости равным 5%.
# 4. Выбрав подходящий вариант статистического теста, проверьте на 5% уровне значимости, есть ли отличия в доходах клиентов в двух группах.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Используя функцию `violinplot()`, постройте скрипичные диаграммы для дохода с группировкой как по признаку «согласие взять потебительский кредит», так и по признаку «использование онлайн-сервисов этого банка».

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ## Часть 2: выбор статистического критерия

# %% [markdown]
# ### Задача 1
#
# Ниже приведены данные об уровнях осадков в двух различных регионах России, измеренные за одинаковые промежутки времени. Проверьте гипотезу о равенстве средних уровней осадков на уровне значимости 5%. При необходимости выполните проверку нормальности.

# %%
reg01 = np.array([105.99, 101.02, 102.83, 103.73, 103.25, 
                  107.59, 105.80, 108.34, 103.98, 102.31])

reg02 = np.array([105.47, 105.28, 105.53, 104.04, 104.85, 
                  104.21, 106.02, 104.54, 103.93, 105.38])

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Ниже приведены данные о температуре в двух различных регионах России, измеренные за одинаковые промежутки времени. Проверьте гипотезу о равенстве средних уровней осадков на уровне значимости 10%. При необходимости выполните проверку нормальности.

# %%
r1 = np.array([3.91191711, 11.85438423, 5.33315539, 15.65024281, 
               1.41290797, 5.81031468, 5.02855113, 6.97657259, 
               5.76103967, 5.79249865])

r2 = np.array([16.81716616, 13.2731672 , 7.43622619, 17.90370181, 
               16.22380383, 5.80146314, 10.15938281, 2.54872913, 
               16.34722055, 10.5265988])

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Дана выборка, содержащая значения индекса Оливье за 2024 год (стоимость приготовления 800 граммов салата «Оливье», вариант с колбасой) в нескольких регионах Сибирском федеральном округе России. Значения индекса округлены до целых.
#
# Считая, что выборка взята из нормального распределения, проверьте на 10%-ном уровне значимости, можно ли считать среднее значение индекса равным 200.

# %%
sample_so = np.array([245, 190, 234, 201, 171, 199, 212, 208])

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4
#
# Даны выборки, содержащие значения индекса Оливье за 2023 и 2024 год (стоимость приготовления 800 граммов салата «Оливье», вариант с колбасой) в регионах Сибирского федерального округа России. Значения индекса округлены до целых.
#
# Считая, что выборки взяты из нормального распределения, проверьте на 1%-ном уровне значимости, можно ли считать средние значения индекса в разные годы, равными.

# %%
so23 = np.array([206, 226, 203, 228, 209, 189, 222, 217, 217, 211])
so24 = np.array([190, 206, 186, 216, 193, 186, 206, 200, 201, 197])

# %%
### YOUR CODE HERE ###
